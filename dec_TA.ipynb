# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('/home/enture/Documents/dec_18_31/0bb30a5b-a9e8-4199-8d95-cd7021f0f8ce_ampl_data.csv')
df.head()
# Out:
#    192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126  5 STAND MILL DRIVE   \
# 0  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126  5 STAND MILL DRIVE
# 1  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126  5 STAND MILL DRIVE
# 2  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126  5 STAND MILL DRIVE
# 3  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126  5 STAND MILL DRIVE
# 4  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126  5 STAND MILL DRIVE
#
#    Current  1671383880  2022-12-18 17:18:00+00   70.75817
# 0  Current  1671383940  2022-12-18 17:19:00+00  70.157555
# 1  Current  1671384000  2022-12-18 17:20:00+00  68.815506
# 2  Current  1671384060  2022-12-18 17:21:00+00  69.799300
# 3  Current  1671384120  2022-12-18 17:22:00+00  70.068665
# 4  Current  1671384180  2022-12-18 17:23:00+00  70.299680

# %%
columns_name = ['Param_id', 'Workspace_Name', 'Meter_Name', 'Param_Name', 'Epoch', 'Timestamp', 'data']
df.columns = columns_name

# %%
df.head()
# Out:
#                          Param_id  Workspace_Name           Meter_Name  \
# 0  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126  5 STAND MILL DRIVE
# 1  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126  5 STAND MILL DRIVE
# 2  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126  5 STAND MILL DRIVE
# 3  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126  5 STAND MILL DRIVE
# 4  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126  5 STAND MILL DRIVE
#
#   Param_Name       Epoch               Timestamp       data
# 0    Current  1671383940  2022-12-18 17:19:00+00  70.157555
# 1    Current  1671384000  2022-12-18 17:20:00+00  68.815506
# 2    Current  1671384060  2022-12-18 17:21:00+00  69.799300
# 3    Current  1671384120  2022-12-18 17:22:00+00  70.068665
# 4    Current  1671384180  2022-12-18 17:23:00+00  70.299680

# %%
df.isnull().sum()
# Out:
# Param_id          0
# Workspace_Name    0
# Meter_Name        0
# Param_Name        0
# Epoch             0
# Timestamp         0
# data              0
# dtype: int64

# %%
df.shape
# Out:
# (33474, 7)

# %%
df['time'] = pd.to_datetime(df['Timestamp'])
df.set_index('Timestamp', inplace=True)
df.head()
# Out:
#                                               Param_id  Workspace_Name  \
# Timestamp
# 2022-12-18 17:19:00+00  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126
# 2022-12-18 17:20:00+00  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126
# 2022-12-18 17:21:00+00  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126
# 2022-12-18 17:22:00+00  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126
# 2022-12-18 17:23:00+00  192.168.13.126,502,9y,5,4,64,2  BHIWADI/9Y/126
#
#                                  Meter_Name Param_Name       Epoch       data  \
# Timestamp
# 2022-12-18 17:19:00+00  5 STAND MILL DRIVE     Current  1671383940  70.157555
# 2022-12-18 17:20:00+00  5 STAND MILL DRIVE     Current  1671384000  68.815506
# 2022-12-18 17:21:00+00  5 STAND MILL DRIVE     Current  1671384060  69.799300
# 2022-12-18 17:22:00+00  5 STAND MILL DRIVE     Current  1671384120  70.068665
# 2022-12-18 17:23:00+00  5 STAND MILL DRIVE     Current  1671384180  70.299680
#
# ...

# %%
df['Param_Name'].unique()
# Out:
# array(['Current', 'Reactive Power', 'Active Power',
#        'Active Energy Consumption', 'Voltage L-N', 'Apparent Power',
#        'Apparent Energy Consumption', 'PF'], dtype=object)

# %%
df_1 = df.pivot(index='time', columns='Param_Name', values='data')
df_1
# Out:
# Param_Name                 Active Energy Consumption  Active Power  \
# time
# 2022-12-18 17:18:00+00:00                  4615239.0      6.626541
# 2022-12-18 17:19:00+00:00                  4615239.5      6.540069
# 2022-12-18 17:20:00+00:00                  4615240.5      6.443836
# 2022-12-18 17:21:00+00:00                  4615241.0      6.518550
# 2022-12-18 17:22:00+00:00                  4615241.5      6.548756
# ...                                              ...           ...
# 2022-12-30 18:25:00+00:00                  4656193.5     55.940517
# 2022-12-30 18:26:00+00:00                  4656197.0     56.753853
# 2022-12-30 18:27:00+00:00                  4656201.0     56.791557
# 2022-12-30 18:28:00+00:00                        NaN           NaN
# 2022-12-30 18:29:00+00:00                  4656205.0     56.814200
#
# Param_Name                 Apparent Energy Consumption  Apparent Power  \
# time
# 2022-12-18 17:18:00+00:00                    6152218.0       15.857847
# ...

# %%
df_1.isnull().sum()
# Out:
# Param_Name
# Active Energy Consumption       313
# Active Power                    436
# Apparent Energy Consumption     313
# Apparent Power                  317
# Current                         431
# PF                             3256
# Reactive Power                  313
# Voltage L-N                     315
# dtype: int64

# %%
df_1.describe()
# Out:
# Param_Name  Active Energy Consumption  Active Power  \
# count                    4.583000e+03   4460.000000
# mean                     4.635125e+06     44.629711
# std                      1.253852e+04     33.110208
# min                      4.615239e+06      3.369883
# 25%                      4.625600e+06      7.314923
# 50%                      4.631093e+06     65.052112
# 75%                      4.649044e+06     70.663414
# max                      4.656205e+06    126.299430
#
# Param_Name  Apparent Energy Consumption  Apparent Power      Current  \
# count                      4.583000e+03     4579.000000  4465.000000
# mean                       6.177527e+06       59.746956   253.876927
# std                        1.603152e+04       37.139917   156.107915
# min                        6.152218e+06       11.983474    54.162620
# 25%                        6.165302e+06       18.076515    78.467750
# 50%                        6.172428e+06       79.889800   337.022670
# ...
